# %% [markdown]
# Creation of Activity Schema
# =======================
#
# We need to create an activity schema with 500 to 1,000 rows meeting the following requirements:
# 1. It must have the design of an active schema (all activities in one table)
# 2. Only a strict sequence `click`&rarr; `lead` &rarr; `consultation` &rarr; `sale` should be considered, i.e., when there is a `click` &rarr; `consultation` or a `sale` &rarr; `sale` &rarr; `consultation` &rarr; `sale` situation, they must be ignored.
# 3. There should be several landing pages,and we are going to count conversion for them
# 4. Finally, we create a query to calculate conversion.

# %% [markdown]
# First, we import packages

# %%
import pandas as pd
import numpy as np
import faker as fake

# %% [markdown]
# We already have a table, `activity_table_peargrape.csv`, and we need to augment it.
# The structure of the table is represented below:
#
# **Column**|**Description**|**Type**|**Required**
# -----|-----|-----|-----
# activity\_id|Unique identifier for the activity record|string|yes
# ts|Timestamp for when the activity occurred|timestamp|yes
# customer|Email as a unique identifier for the customer|string|yes
# activity|Name of the activity based on funnel (`click`, `lead`, `consultation`, `sale`)|string|yes
# anonymous_customer\_id|A unique customer id for cases when `customer` value is null|string|no
# feature\_json|Activity-specific features|JSON|yes
# revenue\_impact|Revenue or cost associated with the activity. Not null only when activity value is `sale`|float|no
# link|URL of a link. . Not null only when activity value is `click` |string|no

# %%
data = pd.read_csv('C:/Mike/Analytics/activity_schema_sample/activity_table_peargrape.csv')

# %%
data
# Out:
#           activity_id                   ts               customer  \
# 0    df3v34dd3fn49sfe  2023-06-01 09:00:00    johndoe@example.com
# 1    g48s6a29sefhcn3d  2023-06-01 09:10:00    janedoe@example.com
# 2    1d8s9a3j29snsf28  2023-06-01 09:15:00       janedoe@acme.com
# 3    f8d73dfg5nswd9f4  2023-06-01 09:20:00  alexsmith@example.com
# 4    4f3g29sf9sdnfld3  2023-06-01 09:25:00                    NaN
# ..                ...                  ...                    ...
# 125      3d9gfnj4sd8f  2023-06-01 19:30:00    johndoe@example.com
# 126       fgn3sd94j3n  2023-06-01 19:35:00                    NaN
# 127       4nsd8g3j9n4  2023-06-01 19:40:00    janedoe@example.com
# 128       jf8d4n3g9sd  2023-06-01 19:45:00       janedoe@acme.com
# 129       39j4nd8g3fs  2023-06-01 19:50:00  alexsmith@example.com
#
#          activity  anonymous_customer_id  \
# 0           click                    NaN
# 1           click                    NaN
# 2           click                    NaN
# 3           click                    NaN
# 4           click  segment_23kdfjdnfjn8r
# ..            ...                    ...
# 125         click                    NaN
# 126  consultation         segment_abd5d3
# 127  consultation                    NaN
# 128         click                    NaN
# 129         click                    NaN
#
#                                           feature_json revenue_impact  \
# 0            {"page": "homepage", "source": "organic"}            NaN
# 1            {"page": "pricing", "source": "referral"}            NaN
# 2            {"page": "homepage", "source": "organic"}            NaN
# 3    {"page": "product_category", "source": "paid_ad"}            NaN
# 4    {"page": "product_category", "source": "paid_ad"}            NaN
# ..                                                 ...            ...
# 125       {"page": "contact_us", "source": "referral"}            NaN
# 126                    {"preferred_time": "afternoon"}            NaN
# 127                      {"preferred_time": "morning"}            NaN
# 128  {"page": "product_category", "source": "paid_ad"}            NaN
# 129      {"page": "testimonials", "source": "organic"}            NaN
#
#                                  link
# 0                 https://example.com
# 1         https://example.com/pricing
# 2        https://example.com/about-us
# 3        https://example.com/products
# 4        https://example.com/products
# ..                                ...
# 125    https://example.com/contact-us
# 126                               NaN
# 127                               NaN
# 128  https://example.com/testimonials
# 129  https://example.com/testimonials
#
# [130 rows x 8 columns]

# %%
data.describe()
# Out:
#              activity_id                   ts             customer activity  \
# count                130                  130                   99      130
# unique               130                  130                    6        4
# top     df3v34dd3fn49sfe  2023-06-01 09:00:00  janedoe@example.com    click
# freq                   1                    1                   37       67
#
#        anonymous_customer_id                   feature_json revenue_impact  \
# count                     31                            130             10
# unique                    10                             18              4
# top           segment_abd5d3  {"form": "newsletter_signup"}          19,99
# freq                       9                             18              5
#
#                                 link
# count                             67
# unique                             7
# top     https://example.com/products
# freq                              18

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   activity_id            130 non-null    object
#  1   ts                     130 non-null    object
#  2   customer               99 non-null     object
#  3   activity               130 non-null    object
#  4   anonymous_customer_id  31 non-null     object
#  5   feature_json           130 non-null    object
#  6   revenue_impact         10 non-null     object
#  7   link                   67 non-null     object
# dtypes: object(8)
# memory usage: 8.2+ KB

# %% [markdown]
# We are going to simplify it by removing columns `activity_id` and `anonymous_customer_id`. All our clients will have ids by email:

# %%
data = data.drop(columns=['activity_id', 'anonymous_customer_id'])

# %%
data
# Out:
#                       ts               customer      activity  \
# 0    2023-06-01 09:00:00    johndoe@example.com         click
# 1    2023-06-01 09:10:00    janedoe@example.com         click
# 2    2023-06-01 09:15:00       janedoe@acme.com         click
# 3    2023-06-01 09:20:00  alexsmith@example.com         click
# 4    2023-06-01 09:25:00                    NaN         click
# ..                   ...                    ...           ...
# 125  2023-06-01 19:30:00    johndoe@example.com         click
# 126  2023-06-01 19:35:00                    NaN  consultation
# 127  2023-06-01 19:40:00    janedoe@example.com  consultation
# 128  2023-06-01 19:45:00       janedoe@acme.com         click
# 129  2023-06-01 19:50:00  alexsmith@example.com         click
#
#                                           feature_json revenue_impact  \
# 0            {"page": "homepage", "source": "organic"}            NaN
# 1            {"page": "pricing", "source": "referral"}            NaN
# 2            {"page": "homepage", "source": "organic"}            NaN
# 3    {"page": "product_category", "source": "paid_ad"}            NaN
# 4    {"page": "product_category", "source": "paid_ad"}            NaN
# ..                                                 ...            ...
# 125       {"page": "contact_us", "source": "referral"}            NaN
# 126                    {"preferred_time": "afternoon"}            NaN
# 127                      {"preferred_time": "morning"}            NaN
# 128  {"page": "product_category", "source": "paid_ad"}            NaN
# 129      {"page": "testimonials", "source": "organic"}            NaN
#
#                                  link
# 0                 https://example.com
# 1         https://example.com/pricing
# 2        https://example.com/about-us
# 3        https://example.com/products
# 4        https://example.com/products
# ..                                ...
# 125    https://example.com/contact-us
# 126                               NaN
# 127                               NaN
# 128  https://example.com/testimonials
# 129  https://example.com/testimonials
#
# [130 rows x 6 columns]

# %% [markdown]
# Now, we are going to add 2,000 more rows with random timestamp

# %% [markdown]
# But first, we are going to change type of certain columns

# %%
data['revenue_impact'] = data['revenue_impact'].str.replace(',','.')

# %%
convert_dict = {
    'customer': str,
    'activity': str,
    'revenue_impact': float,
    'link': str
}

data = data.astype(convert_dict)

# %%
data.head(50)
# Out:
#                      ts                customer      activity  \
# 0   2023-06-01 09:00:00     johndoe@example.com         click
# 1   2023-06-01 09:10:00     janedoe@example.com         click
# 2   2023-06-01 09:15:00        janedoe@acme.com         click
# 3   2023-06-01 09:20:00   alexsmith@example.com         click
# 4   2023-06-01 09:25:00                                 click
# 5   2023-06-01 09:30:00  sarahjones@example.com         click
# 6   2023-06-01 09:35:00     janedoe@example.com         click
# 7   2023-06-01 09:40:00                                 click
# 8   2023-06-01 09:45:00     johndoe@example.com         click
# 9   2023-06-01 09:50:00  sarahsmith@example.com         click
# 10  2023-06-01 09:55:00     johndoe@example.com         click
# 11  2023-06-01 10:00:00                                  lead
# 12  2023-06-01 10:05:00     janedoe@example.com          lead
# 13  2023-06-01 10:10:00                                 click
# 14  2023-06-01 10:15:00   alexsmith@example.com         click
# 15  2023-06-01 10:20:00     janedoe@example.com  consultation
# 16  2023-06-01 10:25:00                                 click
# 17  2023-06-01 10:30:00   alexsmith@example.com          lead
# 18  2023-06-01 10:35:00     johndoe@example.com         click
# 19  2023-06-01 10:40:00     janedoe@example.com         click
# 20  2023-06-01 10:45:00                                 click
# 21  2023-06-01 10:50:00   alexsmith@example.com  consultation
# 22  2023-06-01 10:55:00     janedoe@example.com          lead
# 23  2023-06-01 11:00:00     johndoe@example.com         click
# 24  2023-06-01 11:05:00                                 click
# 25  2023-06-01 11:10:00     janedoe@example.com         click
# 26  2023-06-01 11:15:00        janedoe@acme.com          lead
# 27  2023-06-01 11:20:00   alexsmith@example.com          sale
# 28  2023-06-01 11:25:00     johndoe@example.com          lead
# 29  2023-06-01 11:30:00     janedoe@example.com          sale
# 30  2023-06-01 11:35:00                                 click
# 31  2023-06-01 11:40:00   alexsmith@example.com         click
# 32  2023-06-01 11:45:00     janedoe@example.com         click
# 33  2023-06-01 11:50:00                                 click
# 34  2023-06-01 11:55:00   alexsmith@example.com          lead
# 35  2023-06-01 12:00:00     janedoe@example.com         click
# 36  2023-06-01 12:05:00     johndoe@example.com  consultation
# 37  2023-06-01 12:10:00                                 click
# 38  2023-06-01 12:15:00   alexsmith@example.com         click
# 39  2023-06-01 12:20:00     janedoe@example.com          lead
# 40  2023-06-01 12:25:00     johndoe@example.com          sale
# 41  2023-06-01 12:30:00                                 click
# 42  2023-06-01 12:35:00     janedoe@example.com  consultation
# 43  2023-06-01 12:40:00        janedoe@acme.com  consultation
# 44  2023-06-01 12:45:00   alexsmith@example.com         click
# 45  2023-06-01 12:50:00     johndoe@example.com         click
# 46  2023-06-01 12:55:00     janedoe@example.com         click
# 47  2023-06-01 13:00:00                                 click
# 48  2023-06-01 13:05:00   alexsmith@example.com         click
# 49  2023-06-01 13:10:00     janedoe@example.com         click
#
#                                          feature_json  revenue_impact  \
# 0           {"page": "homepage", "source": "organic"}             NaN
# 1           {"page": "pricing", "source": "referral"}             NaN
# 2           {"page": "homepage", "source": "organic"}             NaN
# 3   {"page": "product_category", "source": "paid_ad"}             NaN
# 4   {"page": "product_category", "source": "paid_ad"}             NaN
# 5           {"page": "about_us", "source": "organic"}             NaN
# 6        {"page": "contact_us", "source": "referral"}             NaN
# 7           {"page": "homepage", "source": "organic"}             NaN
# 8           {"page": "homepage", "source": "organic"}             NaN
# 9   {"page": "product_category", "source": "paid_ad"}             NaN
# 10      {"page": "testimonials", "source": "organic"}             NaN
# 11                      {"form": "newsletter_signup"}             NaN
# 12                           {"form": "website_chat"}             NaN
# 13          {"page": "about_us", "source": "organic"}             NaN
# 14          {"page": "homepage", "source": "organic"}             NaN
# 15                      {"preferred_time": "evening"}             NaN
# 16  {"page": "product_category", "source": "paid_ad"}             NaN
# 17                      {"form": "newsletter_signup"}             NaN
# 18         {"page": "products", "source": "referral"}             NaN
# 19           {"page": "pricing", "source": "paid_ad"}             NaN
# 20          {"page": "homepage", "source": "organic"}             NaN
# 21                    {"preferred_time": "afternoon"}             NaN
# 22                           {"form": "website_chat"}             NaN
# 23       {"page": "contact_us", "source": "referral"}             NaN
# 24          {"page": "homepage", "source": "organic"}             NaN
# 25          {"page": "pricing", "source": "referral"}             NaN
# 26                      {"form": "newsletter_signup"}             NaN
# 27               {"product": "ebook", "price": 19.99}           19.99
# 28                      {"form": "newsletter_signup"}             NaN
# 29               {"product": "ebook", "price": 19.99}           19.99
# 30  {"page": "product_category", "source": "paid_ad"}             NaN
# 31          {"page": "about_us", "source": "organic"}             NaN
# 32         {"page": "products", "source": "referral"}             NaN
# 33  {"page": "product_category", "source": "paid_ad"}             NaN
# 34                           {"form": "website_chat"}             NaN
# 35         {"page": "products", "source": "referral"}             NaN
# 36                      {"preferred_time": "morning"}             NaN
# 37  {"page": "product_category", "source": "paid_ad"}             NaN
# 38          {"page": "pricing", "source": "referral"}             NaN
# 39                           {"form": "website_chat"}             NaN
# 40               {"product": "ebook", "price": 19.99}           19.99
# 41       {"page": "contact_us", "source": "referral"}             NaN
# 42                      {"preferred_time": "morning"}             NaN
# 43                      {"preferred_time": "evening"}             NaN
# 44      {"page": "testimonials", "source": "organic"}             NaN
# 45          {"page": "homepage", "source": "organic"}             NaN
# 46              {"page": "faq", "source": "referral"}             NaN
# 47  {"page": "product_category", "source": "paid_ad"}             NaN
# 48          {"page": "about_us", "source": "organic"}             NaN
# 49      {"page": "testimonials", "source": "organic"}             NaN
#
#                                 link
# 0                https://example.com
# 1        https://example.com/pricing
# 2       https://example.com/about-us
# 3       https://example.com/products
# 4       https://example.com/products
# 5       https://example.com/about-us
# 6     https://example.com/contact-us
# 7                https://example.com
# 8                https://example.com
# 9       https://example.com/products
# 10  https://example.com/testimonials
# 11                               nan
# 12                               nan
# 13      https://example.com/about-us
# 14               https://example.com
# 15                               nan
# 16      https://example.com/products
# 17                               nan
# 18      https://example.com/products
# 19       https://example.com/pricing
# 20               https://example.com
# 21                               nan
# 22                               nan
# 23    https://example.com/contact-us
# 24               https://example.com
# 25       https://example.com/pricing
# 26                               nan
# 27                               nan
# 28                               nan
# 29                               nan
# 30      https://example.com/products
# 31      https://example.com/about-us
# 32      https://example.com/products
# 33      https://example.com/products
# 34                               nan
# 35      https://example.com/products
# 36                               nan
# 37      https://example.com/products
# 38       https://example.com/pricing
# 39                               nan
# 40                               nan
# 41    https://example.com/contact-us
# 42                               nan
# 43                               nan
# 44  https://example.com/testimonials
# 45               https://example.com
# 46           https://example.com/faq
# 47      https://example.com/products
# 48      https://example.com/about-us
# 49  https://example.com/testimonials

# %%
data['customer'] = data['customer'].str.replace('nan', '')

# %%
from datetime import datetime, timedelta
import random

# %%
data_1 = data

# %%
start_date = datetime(2023, 6, 1, 0, 0, 0)
end_date = datetime.now()

# Generate 2000 dummy datetimes
dummy_datetimes = []
for _ in range(2000):
    # Generate a random datetime between the start and end dates
    random_date = start_date + timedelta(seconds=random.randint(0, int((end_date - start_date).total_seconds())))

    # Append the datetime to the list
    dummy_datetimes.append(random_date)

# Convert the list of datetimes to pandas Timestamps
dummy_datetimes = pd.to_datetime(dummy_datetimes)

# Create a new DataFrame with the dummy datetimes
new_rows = pd.DataFrame({'ts': dummy_datetimes})

# Append the new rows to the existing DataFrame
data_1 = data_1.append(new_rows, ignore_index=True)

# %%
data_1
# Out:
#                        ts               customer activity  \
# 0     2023-06-01 09:00:00    johndoe@example.com    click
# 1     2023-06-01 09:10:00    janedoe@example.com    click
# 2     2023-06-01 09:15:00       janedoe@acme.com    click
# 3     2023-06-01 09:20:00  alexsmith@example.com    click
# 4     2023-06-01 09:25:00                           click
# ...                   ...                    ...      ...
# 2125  2023-06-08 15:42:57                    NaN      NaN
# 2126  2023-06-28 10:26:58                    NaN      NaN
# 2127  2023-06-19 22:47:34                    NaN      NaN
# 2128  2023-06-22 04:49:36                    NaN      NaN
# 2129  2023-06-18 01:36:12                    NaN      NaN
#
#                                            feature_json  revenue_impact  \
# 0             {"page": "homepage", "source": "organic"}             NaN
# 1             {"page": "pricing", "source": "referral"}             NaN
# 2             {"page": "homepage", "source": "organic"}             NaN
# 3     {"page": "product_category", "source": "paid_ad"}             NaN
# 4     {"page": "product_category", "source": "paid_ad"}             NaN
# ...                                                 ...             ...
# 2125                                                NaN             NaN
# 2126                                                NaN             NaN
# 2127                                                NaN             NaN
# 2128                                                NaN             NaN
# 2129                                                NaN             NaN
#
#                               link
# 0              https://example.com
# 1      https://example.com/pricing
# 2     https://example.com/about-us
# 3     https://example.com/products
# 4     https://example.com/products
# ...                            ...
# 2125                           NaN
# 2126                           NaN
# 2127                           NaN
# 2128                           NaN
# 2129                           NaN
#
# [2130 rows x 6 columns]

# %%
data_1.activity.unique()
# Out:
# array(['click', 'lead', 'consultation', 'sale', nan], dtype=object)

# %%
random_values = ['click', 'lead', 'consultation', 'sale']

# %%
data_1['activity'] = random.choices(random_values, k=len(data_1))

# %%
data_1
# Out:
#                        ts               customer      activity  \
# 0     2023-06-01 09:00:00    johndoe@example.com          sale
# 1     2023-06-01 09:10:00    janedoe@example.com          lead
# 2     2023-06-01 09:15:00       janedoe@acme.com  consultation
# 3     2023-06-01 09:20:00  alexsmith@example.com          sale
# 4     2023-06-01 09:25:00                                 sale
# ...                   ...                    ...           ...
# 2125  2023-06-08 15:42:57                    NaN         click
# 2126  2023-06-28 10:26:58                    NaN  consultation
# 2127  2023-06-19 22:47:34                    NaN          sale
# 2128  2023-06-22 04:49:36                    NaN         click
# 2129  2023-06-18 01:36:12                    NaN         click
#
#                                            feature_json  revenue_impact  \
# 0             {"page": "homepage", "source": "organic"}             NaN
# 1             {"page": "pricing", "source": "referral"}             NaN
# 2             {"page": "homepage", "source": "organic"}             NaN
# 3     {"page": "product_category", "source": "paid_ad"}             NaN
# 4     {"page": "product_category", "source": "paid_ad"}             NaN
# ...                                                 ...             ...
# 2125                                                NaN             NaN
# 2126                                                NaN             NaN
# 2127                                                NaN             NaN
# 2128                                                NaN             NaN
# 2129                                                NaN             NaN
#
#                               link
# 0              https://example.com
# 1      https://example.com/pricing
# 2     https://example.com/about-us
# 3     https://example.com/products
# 4     https://example.com/products
# ...                            ...
# 2125                           NaN
# 2126                           NaN
# 2127                           NaN
# 2128                           NaN
# 2129                           NaN
#
# [2130 rows x 6 columns]

# %%
data_1['activity'].value_counts()
# Out:
# sale            570
# consultation    538
# click           521
# lead            501
# Name: activity, dtype: int64

# %%
data_1['customer'].value_counts(dropna=False)
# Out:
# NaN                       2000
# janedoe@example.com         37
#                             31
# alexsmith@example.com       29
# johndoe@example.com         23
# janedoe@acme.com             8
# sarahjones@example.com       1
# sarahsmith@example.com       1
# Name: customer, dtype: int64

# %%
customers =['john.doe@example.com',
'emma.smith@example.com',
'alex.wilson@example.com',
'laura.jones@example.com',
'michael.brown@example.com',
'sarah.davis@example.com',
'daniel.thomas@example.com',
'olivia.white@example.com',
'william.martin@example.com',
'emily.jackson@example.com']

data_1['customer'] = random.choices(customers, k=len(data_1))

# %%
data_1
# Out:
#                        ts                    customer      activity  \
# 0     2023-06-01 09:00:00     alex.wilson@example.com          sale
# 1     2023-06-01 09:10:00     laura.jones@example.com          lead
# 2     2023-06-01 09:15:00  william.martin@example.com  consultation
# 3     2023-06-01 09:20:00      emma.smith@example.com          sale
# 4     2023-06-01 09:25:00        john.doe@example.com          sale
# ...                   ...                         ...           ...
# 2125  2023-06-08 15:42:57    olivia.white@example.com         click
# 2126  2023-06-28 10:26:58     sarah.davis@example.com  consultation
# 2127  2023-06-19 22:47:34     sarah.davis@example.com          sale
# 2128  2023-06-22 04:49:36      emma.smith@example.com         click
# 2129  2023-06-18 01:36:12   emily.jackson@example.com         click
#
#                                            feature_json  revenue_impact  \
# 0             {"page": "homepage", "source": "organic"}             NaN
# 1             {"page": "pricing", "source": "referral"}             NaN
# 2             {"page": "homepage", "source": "organic"}             NaN
# 3     {"page": "product_category", "source": "paid_ad"}             NaN
# 4     {"page": "product_category", "source": "paid_ad"}             NaN
# ...                                                 ...             ...
# 2125                                                NaN             NaN
# 2126                                                NaN             NaN
# 2127                                                NaN             NaN
# 2128                                                NaN             NaN
# 2129                                                NaN             NaN
#
#                               link
# 0              https://example.com
# 1      https://example.com/pricing
# 2     https://example.com/about-us
# 3     https://example.com/products
# 4     https://example.com/products
# ...                            ...
# 2125                           NaN
# 2126                           NaN
# 2127                           NaN
# 2128                           NaN
# 2129                           NaN
#
# [2130 rows x 6 columns]

# %%
landing = ['https://www.example.com/special-offer',
'https://www.example.com/limited-time-deal',
'https://www.example.com/exclusive-discount',
'https://www.example.com/new-product-launch',
'https://www.example.com/summer-sale']

def insert_random_landing_page(row):
    if row['activity'] == 'click':
        return random.choice(landing)
    else:
        return row['link']

# Use apply function to update the 'link' column
data_1['link'] = data_1.apply(insert_random_landing_page, axis=1)

# %%
data_1
# Out:
#                        ts                    customer      activity  \
# 0     2023-06-01 09:00:00     alex.wilson@example.com          sale
# 1     2023-06-01 09:10:00     laura.jones@example.com          lead
# 2     2023-06-01 09:15:00  william.martin@example.com  consultation
# 3     2023-06-01 09:20:00      emma.smith@example.com          sale
# 4     2023-06-01 09:25:00        john.doe@example.com          sale
# ...                   ...                         ...           ...
# 2125  2023-06-08 15:42:57    olivia.white@example.com         click
# 2126  2023-06-28 10:26:58     sarah.davis@example.com  consultation
# 2127  2023-06-19 22:47:34     sarah.davis@example.com          sale
# 2128  2023-06-22 04:49:36      emma.smith@example.com         click
# 2129  2023-06-18 01:36:12   emily.jackson@example.com         click
#
#                                            feature_json  revenue_impact  \
# 0             {"page": "homepage", "source": "organic"}             NaN
# 1             {"page": "pricing", "source": "referral"}             NaN
# 2             {"page": "homepage", "source": "organic"}             NaN
# 3     {"page": "product_category", "source": "paid_ad"}             NaN
# 4     {"page": "product_category", "source": "paid_ad"}             NaN
# ...                                                 ...             ...
# 2125                                                NaN             NaN
# 2126                                                NaN             NaN
# 2127                                                NaN             NaN
# 2128                                                NaN             NaN
# 2129                                                NaN             NaN
#
#                                            link
# 0                           https://example.com
# 1                   https://example.com/pricing
# 2                  https://example.com/about-us
# 3                  https://example.com/products
# 4                  https://example.com/products
# ...                                         ...
# 2125      https://www.example.com/special-offer
# 2126                                        NaN
# 2127                                        NaN
# 2128        https://www.example.com/summer-sale
# 2129  https://www.example.com/limited-time-deal
#
# [2130 rows x 6 columns]

# %%
mask = data_1['activity'] != 'click'

# Remove values from the 'link' column where activity is not equal to 'click'
data_1.loc[mask, 'link'] = ''

# %%
data_1
# Out:
#                        ts                    customer      activity  \
# 0     2023-06-01 09:00:00     alex.wilson@example.com          sale
# 1     2023-06-01 09:10:00     laura.jones@example.com          lead
# 2     2023-06-01 09:15:00  william.martin@example.com  consultation
# 3     2023-06-01 09:20:00      emma.smith@example.com          sale
# 4     2023-06-01 09:25:00        john.doe@example.com          sale
# ...                   ...                         ...           ...
# 2125  2023-06-08 15:42:57    olivia.white@example.com         click
# 2126  2023-06-28 10:26:58     sarah.davis@example.com  consultation
# 2127  2023-06-19 22:47:34     sarah.davis@example.com          sale
# 2128  2023-06-22 04:49:36      emma.smith@example.com         click
# 2129  2023-06-18 01:36:12   emily.jackson@example.com         click
#
#                                            feature_json  revenue_impact  \
# 0             {"page": "homepage", "source": "organic"}             NaN
# 1             {"page": "pricing", "source": "referral"}             NaN
# 2             {"page": "homepage", "source": "organic"}             NaN
# 3     {"page": "product_category", "source": "paid_ad"}             NaN
# 4     {"page": "product_category", "source": "paid_ad"}             NaN
# ...                                                 ...             ...
# 2125                                                NaN             NaN
# 2126                                                NaN             NaN
# 2127                                                NaN             NaN
# 2128                                                NaN             NaN
# 2129                                                NaN             NaN
#
#                                            link
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 2125      https://www.example.com/special-offer
# 2126
# 2127
# 2128        https://www.example.com/summer-sale
# 2129  https://www.example.com/limited-time-deal
#
# [2130 rows x 6 columns]

# %%
revenue = [9.99, 15.99, 29.99, 49.99, 99.99]

def insert_random_revenue(row):
    if row['activity'] == 'sale':
        return random.choice(revenue)
    else:
        return row['revenue_impact']

# Use apply function to update the 'link' column
data_1['revenue_impact'] = data_1.apply(insert_random_revenue, axis=1)

# %%
data_1
# Out:
#                        ts                    customer      activity  \
# 0     2023-06-01 09:00:00     alex.wilson@example.com          sale
# 1     2023-06-01 09:10:00     laura.jones@example.com          lead
# 2     2023-06-01 09:15:00  william.martin@example.com  consultation
# 3     2023-06-01 09:20:00      emma.smith@example.com          sale
# 4     2023-06-01 09:25:00        john.doe@example.com          sale
# ...                   ...                         ...           ...
# 2125  2023-06-08 15:42:57    olivia.white@example.com         click
# 2126  2023-06-28 10:26:58     sarah.davis@example.com  consultation
# 2127  2023-06-19 22:47:34     sarah.davis@example.com          sale
# 2128  2023-06-22 04:49:36      emma.smith@example.com         click
# 2129  2023-06-18 01:36:12   emily.jackson@example.com         click
#
#                                            feature_json  revenue_impact  \
# 0             {"page": "homepage", "source": "organic"}           29.99
# 1             {"page": "pricing", "source": "referral"}             NaN
# 2             {"page": "homepage", "source": "organic"}             NaN
# 3     {"page": "product_category", "source": "paid_ad"}           99.99
# 4     {"page": "product_category", "source": "paid_ad"}            9.99
# ...                                                 ...             ...
# 2125                                                NaN             NaN
# 2126                                                NaN             NaN
# 2127                                                NaN           29.99
# 2128                                                NaN             NaN
# 2129                                                NaN             NaN
#
#                                            link
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 2125      https://www.example.com/special-offer
# 2126
# 2127
# 2128        https://www.example.com/summer-sale
# 2129  https://www.example.com/limited-time-deal
#
# [2130 rows x 6 columns]

# %%
data_1.to_csv('C:/Mike/Analytics/activity_schema_table/table_2k.csv', index=False)
